# %%
#Open a text file in 'Write' mode to write the given lines 
f=open("D:\textfile.txt",'w')
f.write("first line\n")
f.write("second line\n")
f.write("third line\n")
f.close()
#Open a text file in 'Read' mode to read and print the available lines-readline function 
k=open("D:\textfile.txt",'r')
print(k.readline())
print(k.readline())
print(k.readline())
k.close()
# Out:
# first line
#
# second line
#
# third line

# %%
#open a text file in append mode
m=open("D:\textfile.txt",'a')
m.write("Fourth line\n")
m.write("Fifth line\n")
m.close()
#open a text file in read mode to read and print the full text
p=open("D:\textfile.txt",'r')
print(p.read())
p.close()
# Out:
# first line
# second line
# third line
# Fourth line
# Fifth line

# %%
with open ("D:\textfile.txt",'r')as file:
    lines=file.readlines()
    print(lines)
# Out:
# ['first line\n', 'second line\n', 'third line\n', 'Fourth line\n', 'Fifth line\n']

# %%
import json
x='{"name":"John","age":30,"city":"New York"}'
#convert json string to python dict
y=json.loads(x)
print(y["age"])
# Out:
# 30

# %%
#python dictionary
data={"name":"John","age":30,"city":"New York"}
#convert python dict to json string
json_data=json.dumps(data)
print(json_data)
# Out:
# {"name": "John", "age": 30, "city": "New York"}
