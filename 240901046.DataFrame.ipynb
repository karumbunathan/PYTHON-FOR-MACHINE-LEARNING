# %%
import pandas as pd 
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
                columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original DataFrame with NaN
#          one       two     three
# a  1.040718  0.647917  2.305241
# b       NaN       NaN       NaN
# c -0.173702 -0.850439  1.929756
# d  0.365820  0.314966  1.369678
# e       NaN       NaN       NaN
# f  1.757801  0.202526  1.371167
#
#
# Dropped DataFrame
#          one       two     three
# a  1.040718  0.647917  2.305241
# c -0.173702 -0.850439  1.929756
# d  0.365820  0.314966  1.369678
# f  1.757801  0.202526  1.371167

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
                columns=['one','two','three'])
df=df.reindex(['a','b','c'])
print("Original DataFrame:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original DataFrame:
#          one       two     three
# a -0.347943 -1.605856  0.341704
# b       NaN       NaN       NaN
# c -0.925017  0.327495 -0.616274
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.347943 -1.605856  0.341704
# b  0.000000  0.000000  0.000000
# c -0.925017  0.327495 -0.616274

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
                 'two':[60,70,80,0,10]})
print("Original DataFrame:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original DataFrame:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
                columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
                                            columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Datafame:\n",df)
print("\nNan - Filled with Background values:\n")
print(df.bfill())
# Out:
# Original Datafame:
#          one       two     three
# a -0.060153  0.494416 -0.614772
# b       NaN       NaN       NaN
# c  0.585442  0.290233  0.358097
# d  0.590062  0.845514 -0.757879
# e       NaN       NaN       NaN
# f -0.206033  0.785823  1.558872
#
# Nan - Filled with Background values:
#
#         one       two     three
# a -0.060153  0.494416 -0.614772
# b  0.585442  0.290233  0.358097
# c  0.585442  0.290233  0.358097
# d  0.590062  0.845514 -0.757879
# e -0.206033  0.785823  1.558872
# f -0.206033  0.785823  1.558872
