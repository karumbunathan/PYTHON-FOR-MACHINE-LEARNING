# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
               columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame with NAN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original DataFrame with NAN
#          one       two     three
# a  0.903891 -0.345842 -0.472375
# b       NaN       NaN       NaN
# c  2.361714 -0.230236  0.000267
# d  0.612590  2.053844  1.103126
# e       NaN       NaN       NaN
# f -1.576140  0.134773  0.014460
#
#
# Dropped DataFrame
#          one       two     three
# a  0.903891 -0.345842 -0.472375
# c  2.361714 -0.230236  0.000267
# d  0.612590  2.053844  1.103126
# f -1.576140  0.134773  0.014460

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
                 columns=['one','two','three'])
df=df.reindex(['a','b','c'])
print("Original DataFrame:\n",df)
print("\n")
print("NAN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original DataFrame:
#          one       two     three
# a -1.204726  0.707473  1.172008
# b       NaN       NaN       NaN
# c -0.125119 -1.100821 -0.961527
#
#
# NAN replaced with '0':
#
#         one       two     three
# a -1.204726  0.707473  1.172008
# b  0.000000  0.000000  0.000000
# c -0.125119 -1.100821 -0.961527

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
                'two':[60,70,80,0,10]})
print("Original DataFrame:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original DataFrame:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
                 columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original DataFrame:
#          one       two     three
# a  2.101351 -1.098484  1.327332
# b       NaN       NaN       NaN
# c  0.437667 -1.344407  0.352884
# d -0.844928  1.036046 -0.368210
# e       NaN       NaN       NaN
# f -0.886186  0.156625 -0.034317
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
                 columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.bfill())
# Out:
# Original DataFrame:
#          one       two     three
# a  0.248748  0.209056  0.519534
# b       NaN       NaN       NaN
# c  0.236881 -0.344372  0.659329
# d  0.865709 -0.394351  1.014031
# e       NaN       NaN       NaN
# f  0.348707 -0.257049  0.959088
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.248748  0.209056  0.519534
# b  0.236881 -0.344372  0.659329
# c  0.236881 -0.344372  0.659329
# d  0.865709 -0.394351  1.014031
# e  0.348707 -0.257049  0.959088
# f  0.348707 -0.257049  0.959088
